# %% [markdown]
# <a href="https://colab.research.google.com/github/Nivetha72006/AI-INTERNSHIP/blob/main/Image_Augmentation_using_Computer_Vision.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import cv2
cv2.__version__
# Out:
# '4.13.0'

# %%
img=cv2.imread("//content/OIP.jpeg")

# %%
img
# Out:
# array([[[ 76,  89, 105],
#         [ 74,  87, 103],
#         [ 75,  86, 100],
#         ...,
#         [ 85, 137, 143],
#         [ 86, 141, 146],
#         [ 91, 146, 151]],
#
#        [[ 74,  87, 103],
#         [ 72,  85, 101],
#         [ 72,  83,  97],
#         ...,
#         [ 82, 134, 140],
#         [ 82, 137, 142],
#         [ 86, 141, 146]],
#
#        [[ 73,  86, 102],
#         [ 71,  84, 100],
#         [ 71,  82,  96],
#         ...,
#         [ 79, 131, 137],
#         [ 76, 131, 136],
#         [ 80, 135, 140]],
#
#        ...,
#
#        [[ 41,  52,  80],
#         [ 38,  50,  78],
#         [ 36,  47,  77],
#         ...,
#         [ 41,  73, 108],
#         [ 65,  84, 119],
#         [ 90, 102, 138]],
#
#        [[ 40,  51,  79],
#         [ 36,  48,  76],
#         [ 33,  44,  74],
#         ...,
#         [ 54,  86, 121],
#         [ 82, 101, 136],
#         [109, 121, 157]],
#
#        [[ 45,  56,  84],
#         [ 38,  50,  78],
#         [ 34,  45,  75],
# ...

# %%
from google.colab.patches import cv2_imshow
cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=RGB size=320x180>

# %%
img2=cv2.imread('/content/OIP.jpeg',0)
cv2_imshow(img2)
# Out:
# <PIL.Image.Image image mode=L size=320x180>

# %%
cv2.imwrite('Vj.jpg',img)
# Out:
# True

# %%
print(img.size)
# Out:
# 172800

# %%
print(img.shape)
# Out:
# (180, 320, 3)

# %%
print(type(img))
# Out:
# <class 'numpy.ndarray'>

# %%
img=img[10:100,40:300]
cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=RGB size=260x90>

# %%
img2=cv2.rotate(img,cv2.ROTATE_90_CLOCKWISE)
from google.colab.patches import cv2_imshow
cv2_imshow(img2)
# Out:
# <PIL.Image.Image image mode=RGB size=90x260>

# %%
img2=cv2.rotate(img,cv2.ROTATE_180)
from google.colab.patches import cv2_imshow
cv2_imshow(img2)
# Out:
# <PIL.Image.Image image mode=RGB size=260x90>

# %%
img2=cv2.rotate(img,cv2.ROTATE_90_COUNTERCLOCKWISE)
from google.colab.patches import cv2_imshow
cv2_imshow(img2)
# Out:
# <PIL.Image.Image image mode=RGB size=90x260>

# %%
img2=cv2.flip(img,1)
from google.colab.patches import cv2_imshow
cv2_imshow(img2)
# Out:
# <PIL.Image.Image image mode=RGB size=260x90>

# %%
img2=cv2.flip(img,0)
from google.colab.patches import cv2_imshow
cv2_imshow(img2)
# Out:
# <PIL.Image.Image image mode=RGB size=260x90>

# %%
img3=cv2.resize(img,(300,300))
from google.colab.patches import cv2_imshow
cv2_imshow(img3)
# Out:
# <PIL.Image.Image image mode=RGB size=300x300>

# %%
img3=cv2.blur(img,(10,20))
from google.colab.patches import cv2_imshow
cv2_imshow(img3)
# Out:
# <PIL.Image.Image image mode=RGB size=260x90>
